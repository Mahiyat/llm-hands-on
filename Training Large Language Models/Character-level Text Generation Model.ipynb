# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# Imports necessary libraries for data manipulation (numpy), deep learning (tensorflow), and text processing (tensorflow.keras.preprocessing.text and tensorflow.keras.preprocessing.sequence).

# %% [markdown]
# **Set Seed for Reproducibility**

# %%
tf.random.set_seed(42)

# %% [markdown]
# Sets a seed for TensorFlow's random number generator to ensure reproducible results.

# %% [markdown]
# **Input Text**

# %%
input_text = '''
Data Science is an interdisciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from noisy, structured and unstructured data.
It combines math and statistics, specialized programming, advanced analytics, artificial intelligence (AI) and machine learning with specific subject matter expertise to uncover actionable insights hidden in an organization’s data.
These insights can be used to guide decision making and strategic planning.
'''

# %% [markdown]
# Defines the input text to be used for training the model.

# %% [markdown]
# **Character to Index Mapping**

# %%
chars = sorted(set(input_text))
char_to_idx = {char: idx for idx, char in enumerate(chars)}
idx_to_char = {idx: char for char, idx in char_to_idx.items()}
num_chars = len(chars)

# %% [markdown]
# *  Creates a set of unique characters in the input text and sorts them.
# *  Creates dictionaries to map each character to an index and vice versa.
# *  Determines the number of unique characters.

# %% [markdown]
# **Prepare Input and Output Sequences**

# %%
input_seq_length = 100
step = 1
input_sequences = []
output_chars = []
for i in range(0, len(input_text) - input_seq_length, step):
  input_seq = input_text[i: i + input_seq_length]
  output_seq = input_text[i + input_seq_length]
  input_sequences.append([char_to_idx[char] for char in input_seq])
  output_chars.append(char_to_idx[output_seq])
x = np.array(input_sequences)
y = to_categorical(output_chars, num_classes=num_chars)

# %% [markdown]
# *  Defines the length of input sequences and the step size for moving through the text.
# *  Creates input sequences of length input_seq_length and corresponding output characters.

# %% [markdown]
# **Convert Sequences to Arrays**

# %%
x_one_hot = np.zeros((x.shape[0], input_seq_length, num_chars))
for i, seq in enumerate(x):
  for j, char in enumerate(seq):
    x_one_hot[i, j, char] = 1

# %% [markdown]
# *  Converts input sequences and output characters to numpy arrays.
# *  One-hot encodes the input sequences to prepare them for training.

# %% [markdown]
# **Define the Model**

# %%
model = Sequential([
    LSTM(128, input_shape=(input_seq_length, num_chars)),
    Dense(num_chars, activation='softmax')
])

# %% [markdown]
# Defines a sequential model with an LSTM layer followed by a Dense layer with a softmax activation.

# %% [markdown]
# **Compile the Model**

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy')

# %% [markdown]
# Compiles the model with the Adam optimizer and categorical crossentropy loss.

# %% [markdown]
# **Train the Model**

# %%
epochs = 100
batch_size = 64
model.fit(x_one_hot, y, epochs = epochs, batch_size = batch_size)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 13ms/step - loss: 3.5920
# Epoch 2/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3.3964
# Epoch 3/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3.0831
# Epoch 4/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0164
# Epoch 5/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2.9966
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2.9915
# Epoch 7/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9799
# Epoch 8/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9814
# Epoch 9/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9742
# Epoch 10/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2.9627
# Epoch 11/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9602
# Epoch 12/100
# 7/7 [==============================] - 0s 6ms/step - loss: 2.9587
# ...

# %% [markdown]
# Trains the model for 100 epochs with a batch size of 64.

# %% [markdown]
# **Generate Text Using the Trained Model**

# %%
def generate_text(model, seed_text, num_chars_to_generate = 100):
  generated_text = seed_text
  for _ in range(num_chars_to_generate):
    x_pred = np.zeros((1, input_seq_length, num_chars))
    for i, char in enumerate(generated_text[-input_seq_length:]):
      x_pred[0, i, char_to_idx[char]] = 1.0
    preds = model.predict(x_pred, verbose=0)[0]
    next_char_idx = np.argmax(preds)
    next_char = idx_to_char[next_char_idx]
    generated_text += next_char
  return generated_text

# %% [markdown]
# *  Defines a function to generate text using the trained model.
# *  Uses the seed text to generate a sequence of characters by predicting the next character iteratively.

# %% [markdown]
# **Generate and Print the Text**

# %%
seed_text = "Data Science is "
generated_text = generate_text(model, seed_text, num_chars_to_generate = 200)
print(generated_text)
# Out:
# Data Science is  siiiiaaiiiiiiimmoaa a   im            sssiiimma       dddddda ttcaaa      s sssttststtte  xxxtrttt coollene end anights srticifis spect mante erterctrond antigts srcticiin  antiltinge t and ecticise

# %% [markdown]
# *  Sets the seed text for text generation.
# *  Generates a sequence of 200 characters starting from the seed text.
# *  Prints the generated text.

# %% [markdown]
# **Summary**<br>
# The code trains a character-level language model using LSTM on a given input text. The trained model can then generate new text based on a seed input by predicting the next character iteratively.

# %% [markdown]
# **Reasons for Output Containing Garbage Characters**<br>
#
#
# *   Limited Training Data
# *   Struggling to Capture Long-range Dependencies
# *   Lack of Contextual Understanding

# %% [markdown]
# **Ways to Improve Quality of Generated Text**<br>
#
#
# *   Larger and Diverse Training Dataset
# *   Using Pre-trained Models
# *   Implementing Sequence-to-sequence Models
# *   Hyperparameter Tuning
# *   Temperature Sampling
